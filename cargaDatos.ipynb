# %%
from pathlib import Path
import pandas as pd

# %%
file_path = Path("sp500_history.parquet")

# Enlace compartido original (evita errores visuales entre I/l)
shared_url = "https://drive.google.com/file/d/1nvubXdAu0EONlrP_yrURZbnPhBQ-uDaB/view?usp=sharing"
file_id = shared_url.split('/d/')[1].split('/')[0]

url_primary = f"https://drive.usercontent.google.com/download?id={file_id}&export=download&confirm=t"
url_fallback = f"https://drive.google.com/uc?export=download&id={file_id}&confirm=t"

if not file_path.exists():
    print("Archivo no encontrado. Descargando desde Google Drive...")
    try:
        df = pd.read_parquet(url_primary)
        used_url = url_primary
    except Exception as e1:
        print("Fallo URL primaria:", type(e1).__name__, e1)
        df = pd.read_parquet(url_fallback)
        used_url = url_fallback
    df.to_parquet(file_path)
    print("Descarga completada desde:", used_url)
else:
    df = pd.read_parquet(file_path)
    print("Archivo local encontrado:", file_path)
# Out:
# file_id usado: 1nvubXdAu0EONlrP_yrURZbnPhBQ-uDaB
# Archivo no encontrado. Descargando desde Google Drive...
# Descarga completada desde: https://drive.usercontent.google.com/download?id=1nvubXdAu0EONlrP_yrURZbnPhBQ-uDaB&export=download&confirm=t

# %%
#Exporto el df como uno nuevo para no modificar el original
df.to_parquet("sp500_history_copy.parquet")
